# %%
import pandas as pd
import numpy as np

#Criar um dataframe com alguns dados faltando

data = {
    'Nome': ['Douglas', 'Jonas', 'Gabriel', 'Kaue', 'Vinicius'],
    'Idade': [20, np.nan, 21, 20, np.nan],
    'Cidade': ['São Paulo', 'São Caetano', np.nan, 'Santo andré', 'São Bernardo'],
    'Salário': [3000, 1500, np.nan, 2000, 4000]
}

dfData = pd.DataFrame(data)

nomeArquivo = 'dados_ausentes.xlsx'
dfData.to_excel(nomeArquivo, index = False)
